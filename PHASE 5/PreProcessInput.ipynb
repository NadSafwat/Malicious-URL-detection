# %%
import math
import requests
import socket
import pickle
import urllib.request
import pandas as pd
import numpy as np
import warnings
import tldextract
import pycountry
import whois
from bs4 import BeautifulSoup

warnings.filterwarnings("ignore", category=UserWarning)

# %%
UserInput = {
    'url': None,
    'url_numOf_digits': None,
    'url_entropy': None,
    'url_len':None,
    'ip_add':None,
    'geo_loc':None,
    'tld':None,
    'who_is':None,
    'https':None,
    'js_len':None,
    'label':None
}

# %% [markdown]
# # Functions

# %%
def count_digits_in_string(s):
    return sum(c.isdigit() for c in s)

def compute_entropy(url):
    char_count = len(url)
    char_freq = {char: url.count(char) / char_count for char in set(url)}
    entropy = -sum(p * math.log2(p) for p in char_freq.values())

    # Normalize the entropy to [0, 1]
    normalized_entropy = entropy / math.log2(char_count)

    return round(normalized_entropy, 5)

def transformIP(ip_add):
    parts = ip_add.split('.')
    return (int(parts[0]) << 24) + (int(parts[1]) << 16) + (int(parts[2]) << 8) + int(parts[3])

def get_ip_address(url):
    try:
        response = requests.get(url)
        hostname = urllib.parse.urlparse(response.url).hostname
        ip_address = socket.gethostbyname(hostname)

        return ip_address
    except:
        return None

def get_js_len(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")

        script_tags = soup.find_all("script")

        total_length = sum(len(tag.text) for tag in script_tags)
        return total_length
    except:
        return 0

def get_geo_loc(url):
    try: 
        response = requests.get(url)
        hostname = urllib.parse.urlparse(response.url).hostname
        ip_address = socket.gethostbyname(hostname)

        # Get geolocation data using IPinfo API (replace with your API key)
        api_key = '89e9d2d437b634'
        url = f"https://ipinfo.io/{ip_address}/json?token={api_key}"
        response = requests.get(url)
        geolocation_data = response.json()
        try:
            country = pycountry.countries.get(alpha_2=geolocation_data['country'])
            return country.name
        except:
            return None
    except:
        return None

def get_tld(url):
    try:
        tld_ext = tldextract.extract(url)
        return tld_ext.suffix
    except:
        return None

# %% [markdown]
# # Get the values

# %%
url = "https://docs.google.com/"

# %%
UserInput['url_numOf_digits'] = count_digits_in_string(url)
UserInput['url_entropy'] = compute_entropy(url)
UserInput['url_len'] = len(url)
UserInput['ip_add'] = get_ip_address(url)
UserInput['who_is'] = 1
UserInput['https'] = 1 if url.startswith('https') else 0
UserInput['js_len'] = get_js_len(url)
UserInput['geo_loc'] = get_geo_loc(url)
UserInput['tld'] = get_tld(url)

# %%
UserInput
# Out:
# {'url_numOf_digits': 0,
#  'url_entropy': 0.79321,
#  'url_len': 24,
#  'ip_add': 2398776916,
#  'who_is': 1,
#  'https': 1,
#  'js_len': 110986,
#  'geo_loc': 'Belgium',
#  'tld': 'com'}

# %%
InptData = pd.DataFrame([UserInput])

# %%
InptData
# Out:
#    url_numOf_digits  url_entropy  url_len      ip_add  who_is  https  js_len  \
# 0                 0      0.79321       24  2398776916       1      1  110986
#
#    geo_loc  tld
# 0  Belgium  com

# %% [markdown]
# # OHE GEO_LOC and TLD

# %%
with open(r"..\PickleFiles\trained_ohe.pkl", "rb") as ohe_file:
    trained_ohe = pickle.load(ohe_file)

ohetransform = trained_ohe.transform(InptData[['geo_loc', 'tld']]).astype('int32')
InptData = pd.concat([InptData,ohetransform], axis=1).drop(columns=['geo_loc', 'tld'])

# %% [markdown]
# # Final input to be sent to model

# %%
InptData
# Out:
#    url_numOf_digits  url_entropy  url_len   ip_add  who_is  https   js_len  \
# 0          -0.33909      0.74338  1.60206  1.51787       1      0  4.19883
#
#    geo_loc_Afghanistan  geo_loc_Albania  geo_loc_Algeria  ...  \
# 0                    0                0                0  ...
#
#    tld_yokohama.jp  tld_yokosuka.kanagawa.jp  tld_z.se  tld_za.com  \
# 0                0                         0         0           0
#
#    tld_za.net  tld_za.org  tld_zagan.pl  tld_zgora.pl  tld_zm  tld_zp.ua
# 0           0           0             0             0       0          0
#
# [1 rows x 1487 columns]

# %%
def get_pred(user_input):
    response = requests.post("http://localhost:5000/predict", json=user_input)
    if response.status_code == 200:
        data = response.json()
        print("Prediction:", data)
    else:
        print("Error:", response.text)

get_pred(url)
# Out:
# Predicted house price: [1]

# %% [markdown]
# # Test

# %%
df = pd.read_csv(r"..\test_dump_v2.csv")

# %%
URLS_1 = df[df['label'] == 1].sample(20)['url'].to_list()
URLS_0 = df[df['label'] == 0].sample(20)['url'].to_list()

# %%
testData = []

for url in URLS_0:
    UserInput['url'] = url
    UserInput['url_numOf_digits'] = count_digits_in_string(url)
    UserInput['url_entropy'] = compute_entropy(url)
    UserInput['url_len'] = len(url)
    UserInput['ip_add'] = get_ip_address(url)
    UserInput['who_is'] = 0
    UserInput['https'] = 1 if url.startswith('https') else 0
    UserInput['js_len'] = get_js_len(url)
    UserInput['geo_loc'] = get_geo_loc(url)
    UserInput['tld'] = get_tld(url)
    UserInput['label'] = 0

    testData.append(UserInput.copy())

# %%
for url in URLS_1:
    UserInput['url'] = url
    UserInput['url_numOf_digits'] = count_digits_in_string(url)
    UserInput['url_entropy'] = compute_entropy(url)
    UserInput['url_len'] = len(url)
    UserInput['ip_add'] = get_ip_address(url)
    UserInput['who_is'] = 0
    UserInput['https'] = 1 if url.startswith('https') else 0
    UserInput['js_len'] = get_js_len(url)
    UserInput['geo_loc'] = get_geo_loc(url)
    UserInput['tld'] = get_tld(url)
    UserInput['label'] = 1

    testData.append(UserInput.copy())

# %%
df = pd.DataFrame.from_dict(testData)
df
# Out:
#                                                   url  url_numOf_digits  \
# 0                       http://www.edgewaterwest.com/                 0
# 1                  http://peca-original.blogspot.com/                 0
# 2                         http://www.voksenfilmer.net                 0
# 3                              http://www.yngmen.com/                 0
# 4               http://groups.yahoo.com/group/ratboat                 0
# 5                          http://www.okinawa315.com/                 3
# 6        http://www.xxx-free-blowjob-porn-videos.com/                 0
# 7                           http://www.ewa-tantra.ch/                 0
# 8                           http://www.brasilporno.tv                 0
# 9          http://www.sweethour.com/shemale-hardcore/                 0
# 10                            http://menagesclub.com/                 0
# 11     http://groups.yahoo.com/group/amorousairwaves/                 0
# 12              http://www.4womenerotica.com/bigrope/                 1
# 13                        http://www.teenievideo.com/                 0
# 14  http://www.henati.net/babes/redheads/fnpenter....                 0
# 15     http://www.all-free-quality-pics.com/danielle/                 0
# 16                        http://www.lovefromanna.com                 0
# 17       http://www.angelfire.com/anime3/hoshinokaze/                 1
# 18      http://www.babezones.com/far_east_beauty.html                 0
# 19             http://www.geocities.com/missbinks420/                 3
# 20                   http://www.customassemblies.com/                 0
# 21    http://www.haverford.edu/athletics/fieldhockey/                 0
# 22         http://www.newadvent.org/cathen/13205b.htm                 5
# 23  http://www.classicbookshelf.com/library/dostoe...                 0
# 24               http://www.mountaingaitedhorses.com/                 0
# 25  http://www.centralconnector.com/games/splitlev...                 0
# 26                          http://www.wikiquote.org/                 0
# 27  http://www.wired.com/wired/archive//3.06/xanad...                 3
# 28                 http://www.ahernmassageschool.com/                 0
# 29  http://www.risa.co.uk/sla/songlist.php?artisti...                 5
# 30                                http://viatalia.com                 0
# 31                http://www.everybodyhateschris.org/                 0
# 32                            http://www.bucklin.org/                 0
# 33                        http://www.sound-files.com/                 0
# 34                        http://www.modemdoctor.com/                 0
# 35                             http://deltakappa.info                 0
# 36                                http://www.lbmc.com                 0
# 37  http://www.goskyhawks.com/index.asp?path=softball                 0
# 38  http://www.geocities.com/crispinlyzard/leper.html                 0
# 39                 http://dnausers.d-n-a.net/cslewis/                 0
#
#     url_entropy  url_len           ip_add        geo_loc    tld  who_is  \
# 0       0.75607       29             None           None    com       0
# 1       0.80191       34   142.251.37.201         France    com       0
# 2       0.84215       27   183.181.82.150          Japan    net       0
# 3       0.82152       22             None           None    com       0
# 4       0.72101       37   87.248.119.252        Germany    com       0
# 5       0.83017       26    183.181.96.15          Japan    com       0
# 6       0.78405       44             None           None    com       0
# 7       0.74582       25   116.202.48.150        Germany     ch       0
# 8       0.83195       25     104.21.18.81  United States     tv       0
# 9       0.73563       42             None           None    com       0
# 10      0.87741       23    173.236.95.18  United States    com       0
# 11      0.71850       46   87.248.119.252        Germany    com       0
# 12      0.76389       37  107.187.173.248  United States    com       0
# 13      0.77984       27    184.94.153.37  United States    com       0
# 14      0.69157       50    5.189.157.246        Germany    net       0
# 15      0.77415       46             None           None    com       0
# 16      0.83245       27      62.72.50.98  United States    com       0
# 17      0.77462       44  209.202.252.105  United States    com       0
# 18      0.77086       45             None           None    com       0
# 19      0.78182       38   87.248.119.252        Germany    com       0
# 20      0.78113       32    199.34.228.59  United States    com       0
# 21      0.75206       47    44.216.239.58  United States    edu       0
# 22      0.78528       42  213.170.143.139          Egypt    org       0
# 23      0.75164       51   216.92.125.178  United States    com       0
# 24      0.79441       36             None           None    com       0
# 25      0.70847       53     45.33.23.183  United States    com       0
# 26      0.79750       25    185.15.58.224         France    org       0
# 27      0.74177       52   199.232.82.194         France    com       0
# 28      0.77725       34    154.198.12.22  United States    com       0
# 29      0.76453       53   54.196.255.208  United States  co.uk       0
# 30      0.83261       19     23.227.38.74         Canada    com       0
# 31      0.79652       35   172.67.201.110  United States    org       0
# 32      0.87015       23   162.215.11.167  United States    org       0
# 33      0.86361       27    81.169.145.86        Germany    com       0
# 34      0.74280       27     209.17.116.2  United States    com       0
# 35      0.83422       22             None           None   info       0
# 36      0.81719       19     45.60.23.136  United States    com       0
# 37      0.78273       49     72.32.86.197  United States    com       0
# 38      0.75091       49   87.248.119.251        Germany    com       0
# 39      0.77878       34             None           None    net       0
#
#     https  js_len  label
# 0       0       0      0
# 1       0   95919      0
# 2       0    2674      0
# 3       0       0      0
# 4       0  262350      0
# 5       0      86      0
# 6       0       0      0
# 7       0       0      0
# 8       0    7895      0
# 9       0       0      0
# 10      0    1225      0
# 11      0  262352      0
# 12      0     417      0
# 13      0    3386      0
# 14      0     915      0
# 15      0       0      0
# 16      0       0      0
# 17      0     355      0
# 18      0       0      0
# 19      0  262350      0
# 20      0   63193      1
# 21      0   38774      1
# 22      0       0      1
# 23      0       0      1
# 24      0       0      1
# 25      0       0      1
# 26      0    1683      1
# 27      0   41989      1
# 28      0       0      1
# 29      0  113132      1
# 30      0   35574      1
# 31      0   27186      1
# 32      0    2765      1
# 33      0       0      1
# 34      0     122      1
# 35      0       0      1
# 36      0   13697      1
# 37      0       0      1
# 38      0  262350      1
# 39      0       0      1

# %%
df.to_csv(r"..\newTest.csv", index=False)
