# %%
import csv
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import pickle

# %%
df_train = pd.read_csv(r'..\train_dump_v2.csv')

# %%
with open(r"..\PickleFiles\trained_ohe.pkl", "rb") as ohe_file:
    trained_ohe = pickle.load(ohe_file)

ohetransform = trained_ohe.transform(df_train[['geo_loc', 'tld']]).astype('int8')
df_train = pd.concat([df_train,ohetransform], axis=1).drop(columns=['geo_loc', 'tld'])

# %%
def transformIP(ip_add):
    if ip_add == '0':
        return 0
    else:
        parts = ip_add.split('.')
        return (int(parts[0]) << 24) + (int(parts[1]) << 16) + (int(parts[2]) << 8) + int(parts[3])

df_train['ip_add'] = df_train.ip_add.apply(transformIP)

# %%
column = df_train.pop('label')
df_train[column.name] = column

# %%
df_test = pd.read_csv(r'..\newTest.csv')

# %%
df_test.ip_add.fillna('0', inplace=True)
# Out:
# C:\Users\nadin\AppData\Local\Temp\ipykernel_1780\2548948836.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test.ip_add.fillna('0', inplace=True)

# %%
ohetransform = trained_ohe.transform(df_test[['geo_loc', 'tld']]).astype('int8')
df_test = pd.concat([df_test,ohetransform], axis=1).drop(columns=['geo_loc', 'tld'])

# %%
df_test['ip_add'] = df_test.ip_add.apply(transformIP)

# %%
column = df_test.pop('label')
df_test[column.name] = column

# %%
# remove the url column thats read from the csv
df_train = df_train.iloc[:, 1:]
df_test = df_test.iloc[:, 1:]

# %%
x_train = df_train[df_train.columns[:-1]]
y_train = df_train['label']

x_test = df_test[df_test.columns[:-1]]
y_test = df_test['label']

# %%
model = RandomForestClassifier(class_weight={0: 20, 1: 1}, max_depth=30)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 20, 1: 1}, max_depth=30)

# %%
Imp = model.feature_importances_
feature_names = x_train.columns

sorted_idx = Imp.argsort()[::-1]
for f in range(x_train.shape[1]):
    print("%d. %s (%f)" % (f + 1, feature_names[sorted_idx[f]], Imp[sorted_idx[f]]))
# Out:
# 1. js_len (0.532317)
# 2. who_is (0.318527)
# 3. tld_org (0.021814)
# 4. tld_edu (0.019246)
# 5. url_numOf_digits (0.017722)
# 6. tld_de (0.016752)
# 7. url_len (0.012156)
# 8. tld_com (0.009366)
# 9. url_entropy (0.008028)
# 10. ip_add (0.004127)
# 11. tld_jp (0.003846)
# 12. tld_co.uk (0.002484)
# 13. tld_ca (0.002039)
# 14. tld_net (0.001961)
# 15. tld_co.jp (0.001942)
# 16. tld_pl (0.001895)
# 17. tld_gov (0.001643)
# 18. tld_org.uk (0.001459)
# 19. tld_ru (0.001450)
# 20. tld_ac.uk (0.001413)
# 21. tld_tv (0.001384)
# 22. tld_dk (0.001161)
# 23. tld_fr (0.001038)
# 24. tld_at (0.000956)
# 25. tld_com.br (0.000933)
# 26. tld_ne.jp (0.000752)
# 27. tld_biz (0.000714)
# 28. tld_ws (0.000692)
# 29. tld_ch (0.000597)
# 30. tld_nl (0.000519)
# 31. tld_ie (0.000428)
# 32. tld_com.au (0.000369)
# 33. tld_edu.au (0.000326)
# 34. tld_cz (0.000310)
# 35. tld_org.au (0.000280)
# 36. geo_loc_United States (0.000247)
# 37. tld_net.au (0.000246)
# 38. tld_blogspot.com (0.000219)
# 39. tld_gr.jp (0.000208)
# 40. geo_loc_China (0.000203)
# 41. geo_loc_Japan (0.000195)
# 42. tld_co.za (0.000192)
# 43. tld_ro (0.000189)
# 44. tld_sk (0.000179)
# 45. tld_com.ar (0.000176)
# 46. tld_nu (0.000153)
# 47. tld_com.tw (0.000149)
# 48. tld_no (0.000149)
# 49. geo_loc_South Korea (0.000142)
# 50. geo_loc_United Kingdom (0.000134)
# 51. geo_loc_Germany (0.000132)
# 52. geo_loc_France (0.000120)
# 53. geo_loc_Australia (0.000116)
# 54. geo_loc_Canada (0.000115)
# 55. tld_gr (0.000114)
# 56. geo_loc_India (0.000114)
# 57. tld_on.ca (0.000106)
# 58. geo_loc_Taiwan (0.000103)
# 59. geo_loc_Sweden (0.000102)
# 60. geo_loc_Brazil (0.000101)
# 61. tld_se (0.000098)
# 62. tld_fi (0.000098)
# 63. geo_loc_Italy (0.000097)
# 64. geo_loc_Netherlands (0.000096)
# 65. tld_ac.jp (0.000093)
# 66. geo_loc_Russia (0.000092)
# 67. tld_gov.au (0.000091)
# 68. tld_co.nz (0.000088)
# 69. tld_sex.pl (0.000086)
# 70. geo_loc_Spain (0.000085)
# 71. tld_org.nz (0.000083)
# 72. geo_loc_Norway (0.000083)
# 73. tld_com.hk (0.000082)
# 74. tld_it (0.000081)
# 75. geo_loc_Argentina (0.000078)
# 76. geo_loc_Egypt (0.000076)
# 77. geo_loc_Austria (0.000074)
# 78. geo_loc_Denmark (0.000073)
# 79. geo_loc_South Africa (0.000070)
# 80. geo_loc_Belgium (0.000070)
# 81. tld_to (0.000069)
# 82. geo_loc_Hong Kong (0.000068)
# 83. tld_lt (0.000065)
# 84. geo_loc_Poland (0.000063)
# 85. tld_gc.ca (0.000058)
# 86. geo_loc_Mexico (0.000057)
# 87. geo_loc_Switzerland (0.000057)
# 88. geo_loc_Morocco (0.000057)
# 89. geo_loc_Saudi Arabia (0.000055)
# 90. tld_mil (0.000054)
# 91. geo_loc_Indonesia (0.000052)
# 92. tld_co.il (0.000051)
# 93. geo_loc_Ireland (0.000050)
# 94. tld_be (0.000049)
# 95. geo_loc_Vietnam (0.000049)
# 96. geo_loc_Colombia (0.000049)
# 97. geo_loc_Finland (0.000048)
# 98. tld_eu (0.000048)
# 99. geo_loc_Chile (0.000047)
# 100. geo_loc_Iran (0.000045)
# 101. tld_es (0.000045)
# 102. geo_loc_Singapore (0.000043)
# 103. geo_loc_Turkey (0.000042)
# 104. geo_loc_Pakistan (0.000041)
# 105. geo_loc_Czechia (0.000037)
# 106. tld_bc.ca (0.000037)
# 107. geo_loc_Israel (0.000037)
# 108. tld_int (0.000037)
# 109. geo_loc_Ukraine (0.000036)
# 110. geo_loc_Rwanda (0.000035)
# 111. tld_fed.us (0.000035)
# 112. geo_loc_New Zealand (0.000034)
# 113. geo_loc_Tunisia (0.000033)
# 114. tld_info (0.000033)
# 115. tld_com.pl (0.000033)
# 116. geo_loc_Namibia (0.000032)
# 117. geo_loc_Thailand (0.000031)
# 118. tld_ms (0.000031)
# 119. tld_gov.uk (0.000031)
# 120. geo_loc_Portugal (0.000031)
# 121. geo_loc_Republic of Lithuania (0.000029)
# 122. geo_loc_Romania (0.000028)
# 123. tld_cc (0.000028)
# 124. https (0.000028)
# 125. geo_loc_Panama (0.000027)
# 126. geo_loc_Costa Rica (0.000026)
# 127. tld_cx (0.000026)
# 128. geo_loc_Philippines (0.000026)
# 129. geo_loc_United Arab Emirates (0.000026)
# 130. tld_us (0.000026)
# 131. geo_loc_Venezuela (0.000026)
# 132. tld_ac.at (0.000025)
# 133. tld_ac.il (0.000023)
# 134. tld_qc.ca (0.000023)
# 135. geo_loc_Oman (0.000023)
# 136. tld_st (0.000023)
# 137. geo_loc_Kazakhstan (0.000023)
# 138. geo_loc_Réunion (0.000022)
# 139. tld_tk (0.000022)
# 140. geo_loc_Hungary (0.000022)
# 141. tld_go.jp (0.000022)
# 142. geo_loc_El Salvador (0.000021)
# 143. geo_loc_Fiji (0.000021)
# 144. geo_loc_Serbia (0.000021)
# 145. geo_loc_Uganda (0.000020)
# 146. geo_loc_Nigeria (0.000020)
# 147. geo_loc_Kenya (0.000020)
# 148. tld_hu (0.000019)
# 149. tld_spb.ru (0.000019)
# 150. geo_loc_Greece (0.000019)
# 151. geo_loc_Peru (0.000018)
# 152. tld_com.my (0.000018)
# 153. geo_loc_Malaysia (0.000017)
# 154. geo_loc_Senegal (0.000017)
# 155. geo_loc_Republic of Moldova (0.000017)
# 156. geo_loc_Mauritius (0.000017)
# 157. geo_loc_Malta (0.000016)
# 158. geo_loc_Uruguay (0.000016)
# 159. geo_loc_Slovenia (0.000016)
# 160. geo_loc_Dominican Republic (0.000015)
# 161. geo_loc_Georgia (0.000015)
# 162. tld_com.sg (0.000015)
# 163. geo_loc_Trinidad and Tobago (0.000015)
# 164. tld_asn.au (0.000015)
# 165. geo_loc_Zambia (0.000015)
# 166. geo_loc_Bosnia and Herzegovina (0.000015)
# 167. geo_loc_Ecuador (0.000015)
# 168. geo_loc_Latvia (0.000015)
# 169. geo_loc_Ghana (0.000015)
# 170. tld_ab.ca (0.000015)
# 171. geo_loc_Macao (0.000014)
# 172. tld_ag (0.000014)
# 173. tld_com.pt (0.000014)
# 174. geo_loc_Croatia (0.000014)
# 175. geo_loc_Bulgaria (0.000014)
# 176. tld_catholic.edu.au (0.000013)
# 177. geo_loc_Iceland (0.000013)
# 178. geo_loc_U.S. Virgin Islands (0.000013)
# 179. geo_loc_Ivory Coast (0.000013)
# 180. tld_org.il (0.000013)
# 181. tld_org.za (0.000012)
# 182. geo_loc_Tanzania (0.000012)
# 183. geo_loc_Belarus (0.000012)
# 184. geo_loc_Algeria (0.000012)
# 185. geo_loc_Estonia (0.000012)
# 186. tld_am (0.000012)
# 187. geo_loc_Luxembourg (0.000012)
# 188. geo_loc_Angola (0.000012)
# 189. tld_si (0.000011)
# 190. geo_loc_Kuwait (0.000011)
# 191. geo_loc_Paraguay (0.000011)
# 192. geo_loc_French Polynesia (0.000011)
# 193. tld_org.ru (0.000011)
# 194. geo_loc_Syria (0.000010)
# 195. geo_loc_Cameroon (0.000010)
# 196. geo_loc_Cyprus (0.000010)
# 197. geo_loc_Madagascar (0.000010)
# 198. tld_ee (0.000010)
# 199. tld_waw.pl (0.000010)
# 200. tld_pt (0.000010)
# 201. tld_mb.ca (0.000009)
# 202. tld_bytom.pl (0.000009)
# 203. geo_loc_North Macedonia (0.000009)
# 204. geo_loc_Iraq (0.000009)
# 205. geo_loc_Burkina Faso (0.000009)
# 206. geo_loc_Bahrain (0.000009)
# 207. geo_loc_Slovakia (0.000009)
# 208. tld_by (0.000009)
# 209. geo_loc_Honduras (0.000009)
# 210. geo_loc_Qatar (0.000009)
# 211. geo_loc_Sudan (0.000009)
# 212. tld_ac.in (0.000008)
# 213. tld_altervista.org (0.000008)
# 214. tld_or.jp (0.000008)
# 215. tld_ac.za (0.000008)
# 216. tld_com.es (0.000008)
# 217. tld_hr (0.000008)
# 218. tld_me.uk (0.000008)
# 219. geo_loc_Puerto Rico (0.000008)
# 220. geo_loc_Azerbaijan (0.000007)
# 221. geo_loc_Palestine (0.000007)
# 222. geo_loc_Albania (0.000007)
# 223. geo_loc_Gabon (0.000007)
# 224. tld_co.kr (0.000007)
# 225. geo_loc_Nicaragua (0.000007)
# 226. tld_tx.us (0.000007)
# 227. geo_loc_Seychelles (0.000007)
# 228. tld_ac.nz (0.000006)
# 229. geo_loc_San Marino (0.000006)
# 230. tld_edu.tr (0.000006)
# 231. geo_loc_Congo Republic (0.000006)
# 232. tld_gov.tw (0.000006)
# 233. tld_ac.kr (0.000006)
# 234. tld_cl (0.000006)
# 235. tld_com.cn (0.000006)
# 236. geo_loc_Bolivia (0.000006)
# 237. geo_loc_Lebanon (0.000006)
# 238. tld_edu.sg (0.000006)
# 239. tld_edu.cn (0.000005)
# 240. tld_net.pl (0.000005)
# 241. tld_in (0.000005)
# 242. geo_loc_Botswana (0.000005)
# 243. tld_fm (0.000005)
# 244. tld_ai (0.000005)
# 245. geo_loc_Guadeloupe (0.000005)
# 246. tld_net.ua (0.000005)
# 247. geo_loc_Jamaica (0.000005)
# 248. tld_nb.ca (0.000005)
# 249. geo_loc_Cambodia (0.000005)
# 250. geo_loc_Armenia (0.000004)
# 251. tld_name (0.000004)
# 252. tld_su (0.000004)
# 253. tld_br (0.000004)
# 254. geo_loc_Yemen (0.000004)
# 255. tld_hk (0.000004)
# 256. geo_loc_Wallis and Futuna (0.000004)
# 257. geo_loc_Gambia (0.000004)
# 258. geo_loc_Isle of Man (0.000004)
# 259. tld_mn.us (0.000004)
# 260. tld_net.nz (0.000004)
# 261. tld_ac.th (0.000004)
# 262. tld_edu.pl (0.000004)
# 263. tld_uk.com (0.000004)
# 264. geo_loc_Bangladesh (0.000004)
# 265. geo_loc_Martinique (0.000003)
# 266. geo_loc_Hashemite Kingdom of Jordan (0.000003)
# 267. tld_au (0.000003)
# 268. geo_loc_New Caledonia (0.000003)
# 269. tld_is (0.000003)
# 270. tld_edu.tw (0.000003)
# 271. tld_com.pk (0.000003)
# 272. geo_loc_Ethiopia (0.000003)
# 273. geo_loc_Togo (0.000003)
# 274. tld_edu.ph (0.000003)
# 275. geo_loc_Mozambique (0.000003)
# 276. tld_coop (0.000003)
# 277. tld_cd (0.000003)
# 278. geo_loc_Samoa (0.000003)
# 279. geo_loc_Suriname (0.000003)
# 280. geo_loc_Cayman Islands (0.000003)
# 281. geo_loc_Central African Republic (0.000003)
# 282. geo_loc_Malawi (0.000003)
# 283. geo_loc_Sint Maarten (0.000003)
# 284. tld_uk.net (0.000002)
# 285. tld_fl.us (0.000002)
# 286. tld_ns.ca (0.000002)
# 287. geo_loc_Guam (0.000002)
# 288. geo_loc_Sri Lanka (0.000002)
# 289. geo_loc_Cuba (0.000002)
# 290. tld_com.tr (0.000002)
# 291. tld_demon.nl (0.000002)
# 292. geo_loc_Mongolia (0.000002)
# 293. geo_loc_Nepal (0.000002)
# 294. tld_va (0.000002)
# 295. tld_lv (0.000002)
# 296. tld_myphotos.cc (0.000002)
# 297. tld_nf (0.000002)
# 298. tld_pri.ee (0.000002)
# 299. geo_loc_Libya (0.000002)
# 300. tld_asso.fr (0.000002)
# 301. geo_loc_Belize (0.000002)
# 302. tld_shop.pl (0.000002)
# 303. geo_loc_Curaçao (0.000002)
# 304. tld_homeip.net (0.000002)
# 305. geo_loc_Bahamas (0.000002)
# 306. geo_loc_Somalia (0.000002)
# 307. tld_ma (0.000002)
# 308. geo_loc_Afghanistan (0.000002)
# 309. tld_shacknet.nu (0.000002)
# 310. tld_com.ru (0.000002)
# 311. geo_loc_Brunei (0.000001)
# 312. geo_loc_Guatemala (0.000001)
# 313. tld_li (0.000001)
# 314. tld_a.se (0.000001)
# 315. geo_loc_Sierra Leone (0.000001)
# 316. tld_pa.us (0.000001)
# 317. geo_loc_Haiti (0.000001)
# 318. geo_loc_Montenegro (0.000001)
# 319. geo_loc_Andorra (0.000001)
# 320. tld_vu (0.000001)
# 321. geo_loc_Maldives (0.000001)
# 322. tld_ca.us (0.000001)
# 323. geo_loc_Eswatini (0.000001)
# 324. tld_ny.us (0.000001)
# 325. tld_edu.hk (0.000001)
# 326. geo_loc_Kyrgyzstan (0.000001)
# 327. tld_nsw.edu.au (0.000001)
# 328. tld_oh.us (0.000001)
# 329. geo_loc_Mayotte (0.000001)
# 330. tld_bg (0.000001)
# 331. tld_co.us (0.000001)
# 332. geo_loc_Djibouti (0.000001)
# 333. tld_vic.edu.au (0.000001)
# 334. tld_az.us (0.000001)
# 335. tld_re (0.000001)
# 336. geo_loc_Myanmar (0.000001)
# 337. geo_loc_Uzbekistan (0.000001)
# 338. tld_ac.be (0.000001)
# 339. geo_loc_Barbados (0.000001)
# 340. tld_lu (0.000001)
# 341. geo_loc_DR Congo (0.000001)
# 342. tld_org.pl (0.000001)
# 343. tld_ltd.uk (0.000001)
# 344. tld_qld.gov.au (0.000001)
# 345. tld_org.hk (0.000001)
# 346. tld_ac (0.000001)
# 347. tld_cc.il.us (0.000001)
# 348. tld_org.sg (0.000001)
# 349. tld_co.in (0.000001)
# 350. tld_nic.in (0.000001)
# 351. geo_loc_Lesotho (0.000000)
# 352. tld_com.cy (0.000000)
# 353. tld_cat (0.000000)
# 354. tld_nc.us (0.000000)
# 355. tld_il.us (0.000000)
# 356. tld_tm (0.000000)
# 357. tld_uk (0.000000)
# 358. geo_loc_Zimbabwe (0.000000)
# 359. tld_dyndns.org (0.000000)
# 360. tld_vic.gov.au (0.000000)
# 361. geo_loc_Aruba (0.000000)
# 362. geo_loc_Gibraltar (0.000000)
# 363. tld_ak.us (0.000000)
# 364. tld_k12.fl.us (0.000000)
# 365. tld_va.us (0.000000)
# 366. tld_edu.my (0.000000)
# 367. tld_k12.ca.us (0.000000)
# 368. tld_ir (0.000000)
# 369. geo_loc_Laos (0.000000)
# 370. tld_ne.us (0.000000)
# 371. tld_res.in (0.000000)
# 372. tld_edu.pk (0.000000)
# 373. tld_cri.nz (0.000000)
# 374. tld_school.nz (0.000000)
# 375. geo_loc_Liberia (0.000000)
# 376. tld_mx (0.000000)
# 377. geo_loc_Monaco (0.000000)
# 378. geo_loc_Antigua and Barbuda (0.000000)
# 379. tld_org.eg (0.000000)
# 380. tld_edu.bb (0.000000)
# 381. tld_org.cn (0.000000)
# 382. geo_loc_Liechtenstein (0.000000)
# 383. geo_loc_Chad (0.000000)
# 384. tld_com.ua (0.000000)
# 385. tld_la.us (0.000000)
# 386. geo_loc_Bermuda (0.000000)
# 387. tld_org.lb (0.000000)
# 388. geo_loc_Guernsey (0.000000)
# 389. tld_gen.nz (0.000000)
# 390. geo_loc_British Virgin Islands (0.000000)
# 391. geo_loc_Benin (0.000000)
# 392. geo_loc_Mali (0.000000)
# 393. tld_ath.cx (0.000000)
# 394. tld_gi (0.000000)
# 395. tld_per.sg (0.000000)
# 396. tld_gov.il (0.000000)
# 397. tld_wa.gov.au (0.000000)
# 398. tld_govt.nz (0.000000)
# 399. tld_cn (0.000000)
# 400. tld_k12.il.us (0.000000)
# 401. tld_co.id (0.000000)
# 402. tld_nh.us (0.000000)
# 403. tld_sa.gov.au (0.000000)
# 404. geo_loc_Guyana (0.000000)
# 405. tld_nf.ca (0.000000)
# 406. tld_pp.se (0.000000)
# 407. geo_loc_Grenada (0.000000)
# 408. tld_k12.mi.us (0.000000)
# 409. geo_loc_Greenland (0.000000)
# 410. geo_loc_Dominica (0.000000)
# 411. tld_ma.us (0.000000)
# 412. tld_gda.pl (0.000000)
# 413. geo_loc_Guinea (0.000000)
# 414. tld_k12.ga.us (0.000000)
# 415. tld_mu (0.000000)
# 416. tld_toscana.it (0.000000)
# 417. tld_vt.us (0.000000)
# 418. tld_lib.mo.us (0.000000)
# 419. tld_go.kr (0.000000)
# 420. tld_id.au (0.000000)
# 421. tld_bham.sch.uk (0.000000)
# 422. tld_md (0.000000)
# 423. tld_org.br (0.000000)
# 424. tld_ga.us (0.000000)
# 425. tld_gov.pl (0.000000)
# 426. geo_loc_Jersey (0.000000)
# 427. tld_gouv.fr (0.000000)
# 428. tld_org.my (0.000000)
# 429. tld_ad (0.000000)
# 430. tld_com.uy (0.000000)
# 431. tld_nj.us (0.000000)
# 432. geo_loc_Niger (0.000000)
# 433. tld_gov.sd (0.000000)
# 434. geo_loc_American Samoa (0.000000)
# 435. tld_lib.va.us (0.000000)
# 436. tld_nv.us (0.000000)
# 437. tld_to.it (0.000000)
# 438. tld_cc.ca.us (0.000000)
# 439. tld_wroc.pl (0.000000)
# 440. geo_loc_Northern Mariana Islands (0.000000)
# 441. tld_ks.us (0.000000)
# 442. tld_ac.ru (0.000000)
# 443. tld_ge (0.000000)
# 444. tld_lib.in.us (0.000000)
# 445. tld_edu.mx (0.000000)
# 446. geo_loc_Tonga (0.000000)
# 447. tld_gov.cy (0.000000)
# 448. tld_suffolk.sch.uk (0.000000)
# 449. tld_no-ip.net (0.000000)
# 450. tld_com.mv (0.000000)
# 451. geo_loc_East Timor (0.000000)
# 452. tld_in.us (0.000000)
# 453. tld_pe.ca (0.000000)
# 454. tld_gov.br (0.000000)
# 455. tld_k12.nc.us (0.000000)
# 456. tld_tn.us (0.000000)
# 457. geo_loc_Kosovo (0.000000)
# 458. tld_nhs.uk (0.000000)
# 459. tld_k12.in.us (0.000000)
# 460. tld_com.mx (0.000000)
# 461. tld_ras.ru (0.000000)
# 462. tld_gb.com (0.000000)
# 463. tld_qld.edu.au (0.000000)
# 464. tld_org.tw (0.000000)
# 465. geo_loc_St Kitts and Nevis (0.000000)
# 466. tld_ba (0.000000)
# 467. tld_or.us (0.000000)
# 468. tld_com.sa (0.000000)
# 469. geo_loc_Anguilla (0.000000)
# 470. tld_hi.us (0.000000)
# 471. tld_servep2p.com (0.000000)
# 472. tld_gov.za (0.000000)
# 473. tld_sd.us (0.000000)
# 474. tld_k12.ia.us (0.000000)
# 475. tld_poznan.pl (0.000000)
# 476. tld_ut.us (0.000000)
# 477. tld_wa.us (0.000000)
# 478. tld_eu.org (0.000000)
# 479. tld_bm (0.000000)
# 480. tld_cc.va.us (0.000000)
# 481. tld_edu.np (0.000000)
# 482. tld_org.in (0.000000)
# 483. tld_net.tt (0.000000)
# 484. tld_wv.us (0.000000)
# 485. tld_herts.sch.uk (0.000000)
# 486. tld_k12.ny.us (0.000000)
# 487. tld_sg (0.000000)
# 488. geo_loc_French Guiana (0.000000)
# 489. tld_vg (0.000000)
# 490. tld_tas.edu.au (0.000000)
# 491. geo_loc_Bhutan (0.000000)
# 492. tld_lib.ks.us (0.000000)
# 493. tld_ad.jp (0.000000)
# 494. tld_gob.mx (0.000000)
# 495. tld_act.edu.au (0.000000)
# 496. tld_k12.md.us (0.000000)
# 497. tld_edu.mo (0.000000)
# 498. tld_gov.mo (0.000000)
# 499. tld_gov.tr (0.000000)
# 500. geo_loc_Faroe Islands (0.000000)
# 501. tld_sytes.net (0.000000)
# 502. tld_net.cn (0.000000)
# 503. tld_edu.sa (0.000000)
# 504. tld_nt.edu.au (0.000000)
# 505. tld_ok.us (0.000000)
# 506. tld_ac.cn (0.000000)
# 507. geo_loc_South Sudan (0.000000)
# 508. geo_loc_Solomon Islands (0.000000)
# 509. tld_gov.sy (0.000000)
# 510. tld_org.gy (0.000000)
# 511. tld_nagoya.jp (0.000000)
# 512. tld_k12.or.us (0.000000)
# 513. tld_ind.tn (0.000000)
# 514. tld_gov.in (0.000000)
# 515. tld_ac.ug (0.000000)
# 516. tld_or.id (0.000000)
# 517. tld_edu.mt (0.000000)
# 518. tld_ms.us (0.000000)
# 519. tld_co.ke (0.000000)
# 520. tld_sk.ca (0.000000)
# 521. tld_org.mx (0.000000)
# 522. tld_servehttp.com (0.000000)
# 523. tld_com.jo (0.000000)
# 524. tld_yokohama.jp (0.000000)
# 525. tld_miyagi.jp (0.000000)
# 526. tld_yamanashi.jp (0.000000)
# 527. tld_wi.us (0.000000)
# 528. tld_nd.us (0.000000)
# 529. tld_k12.la.us (0.000000)
# 530. tld_aw (0.000000)
# 531. tld_co.ae (0.000000)
# 532. tld_lib.ak.us (0.000000)
# 533. tld_krakow.pl (0.000000)
# 534. tld_mk.ua (0.000000)
# 535. tld_k12.vt.us (0.000000)
# 536. tld_edu.eg (0.000000)
# 537. tld_edu.lb (0.000000)
# 538. geo_loc_Turkmenistan (0.000000)
# 539. tld_gov.sg (0.000000)
# 540. tld_gov.mu (0.000000)
# 541. tld_web.id (0.000000)
# 542. tld_cc.al.us (0.000000)
# 543. tld_md.us (0.000000)
# 544. tld_ct.us (0.000000)
# 545. tld_gob.sv (0.000000)
# 546. tld_co.th (0.000000)
# 547. tld_sh (0.000000)
# 548. tld_yk.ca (0.000000)
# 549. tld_cc.tx.us (0.000000)
# 550. geo_loc_Cook Islands (0.000000)
# 551. tld_florence.it (0.000000)
# 552. geo_loc_Palau (0.000000)
# 553. tld_ed.jp (0.000000)
# 554. tld_k12.az.us (0.000000)
# 555. tld_tas.gov.au (0.000000)
# 556. tld_k12.ma.us (0.000000)
# 557. tld_id.us (0.000000)
# 558. tld_nm.us (0.000000)
# 559. tld_kharkov.ua (0.000000)
# 560. tld_com.ph (0.000000)
# 561. tld_org.ua (0.000000)
# 562. tld_gov.tt (0.000000)
# 563. tld_lib.ia.us (0.000000)
# 564. tld_lublin.pl (0.000000)
# 565. geo_loc_Mauritania (0.000000)
# 566. tld_cc.ms.us (0.000000)
# 567. tld_eu.int (0.000000)
# 568. tld_com.np (0.000000)
# 569. tld_re.kr (0.000000)
# 570. tld_wy.us (0.000000)
# 571. tld_edu.om (0.000000)
# 572. tld_k12.il (0.000000)
# 573. tld_k12.va.us (0.000000)
# 574. tld_kiev.ua (0.000000)
# 575. tld_gov.bm (0.000000)
# 576. tld_tn.it (0.000000)
# 577. tld_wa.edu.au (0.000000)
# 578. tld_servegame.org (0.000000)
# 579. tld_com.co (0.000000)
# 580. tld_ar (0.000000)
# 581. tld_com.mk (0.000000)
# 582. tld_oz.au (0.000000)
# 583. tld_lug.org.uk (0.000000)
# 584. tld_gov.jo (0.000000)
# 585. tld_fo (0.000000)
# 586. tld_gov.np (0.000000)
# 587. tld_edu.bn (0.000000)
# 588. tld_org.im (0.000000)
# 589. tld_gotdns.com (0.000000)
# 590. tld_org.co (0.000000)
# 591. tld_nsn.us (0.000000)
# 592. tld_aero (0.000000)
# 593. tld_mi.it (0.000000)
# 594. tld_lib.oh.us (0.000000)
# 595. tld_or.at (0.000000)
# 596. tld_me.us (0.000000)
# 597. tld_com.ve (0.000000)
# 598. tld_or.th (0.000000)
# 599. tld_vn (0.000000)
# 600. geo_loc_Vatican City (0.000000)
# 601. tld_pe.kr (0.000000)
# 602. tld_lib.mi.us (0.000000)
# 603. tld_k12.ar.us (0.000000)
# 604. tld_tn (0.000000)
# 605. tld_ac.cr (0.000000)
# 606. tld_shiga.jp (0.000000)
# 607. tld_gov.kw (0.000000)
# 608. tld_eq.edu.au (0.000000)
# 609. tld_wakkanai.hokkaido.jp (0.000000)
# 610. tld_org.sa (0.000000)
# 611. tld_cc.mo.us (0.000000)
# 612. geo_loc_Papua New Guinea (0.000000)
# 613. geo_loc_Burundi (0.000000)
# 614. tld_al.us (0.000000)
# 615. geo_loc_Saint Lucia (0.000000)
# 616. tld_servebbs.com (0.000000)
# 617. tld_org.fk (0.000000)
# 618. tld_org.gg (0.000000)
# 619. tld_edu.ar (0.000000)
# 620. tld_k12.ut.us (0.000000)
# 621. tld_godo.gifu.jp (0.000000)
# 622. tld_org.ar (0.000000)
# 623. tld_org.mk (0.000000)
# 624. tld_lib.nh.us (0.000000)
# 625. tld_co.at (0.000000)
# 626. tld_co.tz (0.000000)
# 627. tld_org.bw (0.000000)
# 628. tld_k12.pa.us (0.000000)
# 629. tld_mt.us (0.000000)
# 630. tld_org.ph (0.000000)
# 631. tld_yamanakako.yamanashi.jp (0.000000)
# 632. tld_k12.sc.us (0.000000)
# 633. tld_net.uk (0.000000)
# 634. tld_priv.no (0.000000)
# 635. tld_or.kr (0.000000)
# 636. geo_loc_Saint Helena (0.000000)
# 637. tld_olsztyn.pl (0.000000)
# 638. tld_ar.us (0.000000)
# 639. tld_iwate.jp (0.000000)
# 640. tld_tc (0.000000)
# 641. tld_gov.af (0.000000)
# 642. tld_mi.us (0.000000)
# 643. tld_lib.ny.us (0.000000)
# 644. tld_osaka.jp (0.000000)
# 645. tld_art.pl (0.000000)
# 646. tld_km.ua (0.000000)
# 647. tld_gv.at (0.000000)
# 648. tld_gdynia.pl (0.000000)
# 649. tld_debian.net (0.000000)
# 650. tld_kr.ua (0.000000)
# 651. tld_mie.jp (0.000000)
# 652. tld_northumberland.sch.uk (0.000000)
# 653. tld_com.eg (0.000000)
# 654. tld_yamatokoriyama.nara.jp (0.000000)
# 655. tld_com.tn (0.000000)
# 656. tld_re.it (0.000000)
# 657. tld_cc.ia.us (0.000000)
# 658. tld_zgora.pl (0.000000)
# 659. tld_sayama.saitama.jp (0.000000)
# 660. tld_gov.ph (0.000000)
# 661. tld_dep.no (0.000000)
# 662. tld_museum (0.000000)
# 663. tld_sm (0.000000)
# 664. tld_edu.mk (0.000000)
# 665. tld_edu.gr (0.000000)
# 666. tld_ao (0.000000)
# 667. tld_dazaifu.fukuoka.jp (0.000000)
# 668. geo_loc_Åland (0.000000)
# 669. tld_lib.il.us (0.000000)
# 670. tld_ac.cy (0.000000)
# 671. tld_bz (0.000000)
# 672. tld_tm.fr (0.000000)
# 673. geo_loc_Cabo Verde (0.000000)
# 674. tld_kz (0.000000)
# 675. tld_de.us (0.000000)
# 676. tld_prato.it (0.000000)
# 677. tld_lg.jp (0.000000)
# 678. tld_miyazaki.jp (0.000000)
# 679. geo_loc_Tajikistan (0.000000)
# 680. tld_mo.us (0.000000)
# 681. tld_com.ky (0.000000)
# 682. geo_loc_Saint Martin (0.000000)
# 683. tld_ia.us (0.000000)
# 684. tld_mt (0.000000)
# 685. tld_k12.id.us (0.000000)
# 686. tld_org.pr (0.000000)
# 687. tld_ac.ir (0.000000)
# 688. tld_k12.me.us (0.000000)
# 689. tld_opole.pl (0.000000)
# 690. tld_edu.kw (0.000000)
# 691. tld_gov.ar (0.000000)
# 692. tld_mc (0.000000)
# 693. tld_com.pe (0.000000)
# 694. tld_edu.vn (0.000000)
# 695. tld_info.pl (0.000000)
# 696. tld_com.pg (0.000000)
# 697. tld_kg (0.000000)
# 698. tld_gov.bn (0.000000)
# 699. tld_gov.hk (0.000000)
# 700. tld_net.pk (0.000000)
# 701. tld_odawara.kanagawa.jp (0.000000)
# 702. tld_swidnik.pl (0.000000)
# 703. geo_loc_Marshall Islands (0.000000)
# 704. tld_go.th (0.000000)
# 705. tld_homedns.org (0.000000)
# 706. geo_loc_French Southern Territories (0.000000)
# 707. tld_k12.ks.us (0.000000)
# 708. tld_com.qa (0.000000)
# 709. tld_eu.com (0.000000)
# 710. geo_loc_São Tomé and Príncipe (0.000000)
# 711. tld_mine.nu (0.000000)
# 712. tld_edu.ru (0.000000)
# 713. geo_loc_Federated States of Micronesia (0.000000)
# 714. tld_ly (0.000000)
# 715. tld_org.pg (0.000000)
# 716. tld_as (0.000000)
# 717. tld_org.tr (0.000000)
# 718. tld_ac.lk (0.000000)
# 719. tld_nfshost.com (0.000000)
# 720. tld_gov.ng (0.000000)
# 721. tld_com.ai (0.000000)
# 722. tld_k12.mt.us (0.000000)
# 723. geo_loc_Saint Pierre and Miquelon (0.000000)
# 724. tld_edu.jo (0.000000)
# 725. tld_ky.us (0.000000)
# 726. tld_com.lb (0.000000)
# 727. tld_crimea.ua (0.000000)
# 728. tld_bf (0.000000)
# 729. tld_dc.us (0.000000)
# 730. tld_bathnes.sch.uk (0.000000)
# 731. tld_cc.az.us (0.000000)
# 732. tld_cc.co.us (0.000000)
# 733. tld_com.vn (0.000000)
# 734. tld_cr (0.000000)
# 735. tld_cardiff.sch.uk (0.000000)
# 736. tld_cu (0.000000)
# 737. tld_date.fukushima.jp (0.000000)
# 738. tld_catania.it (0.000000)
# 739. tld_czest.pl (0.000000)
# 740. tld_cumbria.sch.uk (0.000000)
# 741. tld_ac.ci (0.000000)
# 742. geo_loc_Antarctica (0.000000)
# 743. tld_com.zm (0.000000)
# 744. tld_com.ye (0.000000)
# 745. tld_ac.id (0.000000)
# 746. geo_loc_Saint Barthélemy (0.000000)
# 747. tld_com.vu (0.000000)
# 748. tld_ac.ae (0.000000)
# 749. tld_ac.bd (0.000000)
# 750. tld_ac.fj (0.000000)
# 751. tld_cunha.nom.br (0.000000)
# 752. tld_bb (0.000000)
# 753. tld_dontexist.com (0.000000)
# 754. tld_derbyshire.sch.uk (0.000000)
# 755. tld_devon.sch.uk (0.000000)
# 756. tld_bs.it (0.000000)
# 757. tld_e-sussex.sch.uk (0.000000)
# 758. geo_loc_Turks and Caicos Islands (0.000000)
# 759. tld_bs (0.000000)
# 760. tld_ealing.sch.uk (0.000000)
# 761. tld_bromley.sch.uk (0.000000)
# 762. tld_bristol.sch.uk (0.000000)
# 763. tld_brighton-hove.sch.uk (0.000000)
# 764. tld_ec (0.000000)
# 765. tld_brent.sch.uk (0.000000)
# 766. tld_biz.pl (0.000000)
# 767. tld_ed.cr (0.000000)
# 768. tld_bplaced.net (0.000000)
# 769. tld_bologna.it (0.000000)
# 770. tld_bo.it (0.000000)
# 771. geo_loc_Guinea-Bissau (0.000000)
# 772. tld_edu.al (0.000000)
# 773. tld_biz.tr (0.000000)
# 774. geo_loc_Nauru (0.000000)
# 775. tld_edu.az (0.000000)
# 776. tld_edu.ba (0.000000)
# 777. tld_biz.ua (0.000000)
# 778. tld_edu.bd (0.000000)
# 779. tld_edu.bh (0.000000)
# 780. tld_blogdns.com (0.000000)
# 781. tld_dz (0.000000)
# 782. tld_bt (0.000000)
# 783. geo_loc_Tuvalu (0.000000)
# 784. tld_cc.fl.us (0.000000)
# 785. tld_dj (0.000000)
# 786. tld_bg.it (0.000000)
# 787. tld_dni.us (0.000000)
# 788. tld_bz.it (0.000000)
# 789. geo_loc_Niue (0.000000)
# 790. geo_loc_Vanuatu (0.000000)
# 791. tld_dnsalias.net (0.000000)
# 792. tld_dnsalias.org (0.000000)
# 793. tld_dnsdojo.com (0.000000)
# 794. tld_donetsk.ua (0.000000)
# 795. geo_loc_Kiribati (0.000000)
# 796. tld_bi (0.000000)
# 797. tld_dyndns.info (0.000000)
# 798. tld_dorset.sch.uk (0.000000)
# 799. tld_bydgoszcz.pl (0.000000)
# 800. tld_bialowieza.pl (0.000000)
# 801. tld_dp.ua (0.000000)
# 802. tld_dreamhosters.com (0.000000)
# 803. tld_biz.pk (0.000000)
# 804. tld_durham.sch.uk (0.000000)
# 805. tld_dyn-o-saur.com (0.000000)
# 806. tld_dynalias.com (0.000000)
# 807. tld_bw (0.000000)
# 808. tld_dyndns.biz (0.000000)
# 809. tld_ac.ke (0.000000)
# 810. tld_ch.eu.org (0.000000)
# 811. tld_bath.sch.uk (0.000000)
# 812. tld_com.bo (0.000000)
# 813. tld_al (0.000000)
# 814. tld_akita.jp (0.000000)
# 815. tld_cc.tn.us (0.000000)
# 816. tld_co.tt (0.000000)
# 817. tld_cc.or.us (0.000000)
# 818. tld_co.ug (0.000000)
# 819. tld_cc.ok.us (0.000000)
# 820. tld_cc.oh.us (0.000000)
# 821. tld_akashi.hyogo.jp (0.000000)
# 822. tld_co.ve (0.000000)
# 823. tld_cc.ny.us (0.000000)
# 824. tld_co.zm (0.000000)
# 825. tld_co.zw (0.000000)
# 826. tld_aichi.jp (0.000000)
# 827. tld_agano.niigata.jp (0.000000)
# 828. tld_af (0.000000)
# 829. tld_aeroport.fr (0.000000)
# 830. tld_com.az (0.000000)
# 831. tld_com.bb (0.000000)
# 832. tld_cc.nm.us (0.000000)
# 833. tld_com.bd (0.000000)
# 834. tld_com.bh (0.000000)
# 835. tld_cc.nj.us (0.000000)
# 836. tld_com.bn (0.000000)
# 837. tld_ae (0.000000)
# 838. tld_co.sz (0.000000)
# 839. tld_co.om (0.000000)
# 840. tld_cc.wa.us (0.000000)
# 841. tld_co.bw (0.000000)
# 842. tld_art.br (0.000000)
# 843. tld_chiba.jp (0.000000)
# 844. tld_arakawa.tokyo.jp (0.000000)
# 845. tld_cistron.nl (0.000000)
# 846. tld_ck (0.000000)
# 847. tld_ck.ua (0.000000)
# 848. tld_art.museum (0.000000)
# 849. tld_aomori.jp (0.000000)
# 850. tld_co (0.000000)
# 851. tld_cci.fr (0.000000)
# 852. tld_cc.wy.us (0.000000)
# 853. tld_co.ck (0.000000)
# 854. tld_co.mz (0.000000)
# 855. geo_loc_British Indian Ocean Territory (0.000000)
# 856. tld_co.cr (0.000000)
# 857. tld_co.fk (0.000000)
# 858. tld_co.hu (0.000000)
# 859. tld_anthropology.museum (0.000000)
# 860. tld_co.im (0.000000)
# 861. tld_co.it (0.000000)
# 862. tld_anglesey.sch.uk (0.000000)
# 863. tld_aland.fi (0.000000)
# 864. geo_loc_Bonaire, Sint Eustatius, and Saba (0.000000)
# 865. tld_co.ls (0.000000)
# 866. tld_adv.br (0.000000)
# 867. tld_asia (0.000000)
# 868. tld_barnet.sch.uk (0.000000)
# 869. tld_com.bt (0.000000)
# 870. tld_ac.pg (0.000000)
# 871. tld_com.na (0.000000)
# 872. tld_com.nf (0.000000)
# 873. tld_com.ni (0.000000)
# 874. tld_az (0.000000)
# 875. tld_ac.pa (0.000000)
# 876. tld_com.pa (0.000000)
# 877. tld_cc.mi.us (0.000000)
# 878. tld_ac.mz (0.000000)
# 879. tld_cc.md.us (0.000000)
# 880. tld_com.py (0.000000)
# 881. tld_ac.mw (0.000000)
# 882. tld_cheshire.sch.uk (0.000000)
# 883. tld_com.ro (0.000000)
# 884. tld_cc.la.us (0.000000)
# 885. tld_ac.mu (0.000000)
# 886. tld_com.sb (0.000000)
# 887. tld_com.sc (0.000000)
# 888. tld_ac.ma (0.000000)
# 889. tld_cc.ks.us (0.000000)
# 890. tld_com.sl (0.000000)
# 891. tld_com.sv (0.000000)
# 892. geo_loc_Saint Vincent and the Grenadines (0.000000)
# 893. geo_loc_Equatorial Guinea (0.000000)
# 894. tld_com.sy (0.000000)
# 895. tld_ac.rw (0.000000)
# 896. tld_com.mt (0.000000)
# 897. tld_ac.tz (0.000000)
# 898. tld_com.fr (0.000000)
# 899. tld_com.by (0.000000)
# 900. tld_edu.bz (0.000000)
# 901. tld_aso.kumamoto.jp (0.000000)
# 902. tld_ac.zw (0.000000)
# 903. tld_blog.br (0.000000)
# 904. tld_com.do (0.000000)
# 905. tld_com.ec (0.000000)
# 906. tld_cc.nd.us (0.000000)
# 907. tld_cc.nc.us (0.000000)
# 908. tld_cc.mt.us (0.000000)
# 909. tld_com.fj (0.000000)
# 910. tld_ac.vn (0.000000)
# 911. tld_com.mo (0.000000)
# 912. tld_com.ge (0.000000)
# 913. tld_com.gh (0.000000)
# 914. tld_com.gr (0.000000)
# 915. tld_com.gt (0.000000)
# 916. tld_com.hr (0.000000)
# 917. tld_com.jm (0.000000)
# 918. tld_asti.it (0.000000)
# 919. tld_com.kh (0.000000)
# 920. tld_com.kw (0.000000)
# 921. tld_ax (0.000000)
# 922. tld_com.mm (0.000000)
# 923. tld_blackpool.sch.uk (0.000000)
# 924. tld_zp.ua (0.000000)
# 925. tld_edu.co (0.000000)
# 926. tld_org.gr (0.000000)
# 927. tld_org.ee (0.000000)
# 928. tld_org.es (0.000000)
# 929. tld_org.et (0.000000)
# 930. tld_org.fj (0.000000)
# 931. tld_org.ge (0.000000)
# 932. tld_org.gh (0.000000)
# 933. tld_org.hu (0.000000)
# 934. tld_org.bz (0.000000)
# 935. tld_org.ir (0.000000)
# 936. tld_org.je (0.000000)
# 937. tld_org.jm (0.000000)
# 938. tld_org.kh (0.000000)
# 939. tld_org.kw (0.000000)
# 940. tld_org.ky (0.000000)
# 941. tld_org.cy (0.000000)
# 942. tld_org.bt (0.000000)
# 943. tld_pn (0.000000)
# 944. tld_or.cr (0.000000)
# 945. tld_of.by (0.000000)
# 946. tld_okayama.jp (0.000000)
# 947. tld_okayama.okayama.jp (0.000000)
# 948. tld_okinawa.jp (0.000000)
# 949. tld_om (0.000000)
# 950. tld_omachi.nagano.jp (0.000000)
# 951. tld_or.ke (0.000000)
# 952. tld_org.bh (0.000000)
# 953. tld_or.tz (0.000000)
# 954. tld_or.ug (0.000000)
# 955. tld_org.ac (0.000000)
# 956. tld_org.al (0.000000)
# 957. tld_org.ba (0.000000)
# 958. tld_org.bb (0.000000)
# 959. tld_org.lc (0.000000)
# 960. tld_org.lr (0.000000)
# 961. tld_org.ls (0.000000)
# 962. tld_ozu.kumamoto.jp (0.000000)
# 963. tld_org.vu (0.000000)
# 964. tld_org.zw (0.000000)
# 965. tld_ota.gunma.jp (0.000000)
# 966. tld_otake.hiroshima.jp (0.000000)
# 967. tld_otsu.shiga.jp (0.000000)
# 968. tld_ozu.ehime.jp (0.000000)
# 969. tld_pa (0.000000)
# 970. tld_org.ma (0.000000)
# 971. tld_pf (0.000000)
# 972. tld_ph (0.000000)
# 973. tld_piemonte.it (0.000000)
# 974. tld_pisa.it (0.000000)
# 975. tld_pk (0.000000)
# 976. tld_plc.uk (0.000000)
# 977. tld_org.vn (0.000000)
# 978. tld_org.ve (0.000000)
# 979. tld_org.uy (0.000000)
# 980. tld_org.tt (0.000000)
# 981. tld_org.tn (0.000000)
# 982. tld_org.sz (0.000000)
# 983. tld_org.sv (0.000000)
# 984. tld_org.rw (0.000000)
# 985. tld_org.pk (0.000000)
# 986. tld_org.pf (0.000000)
# 987. tld_org.pe (0.000000)
# 988. tld_org.np (0.000000)
# 989. tld_org.ng (0.000000)
# 990. tld_org.na (0.000000)
# 991. tld_org.mz (0.000000)
# 992. tld_org.mw (0.000000)
# 993. tld_org.mt (0.000000)
# 994. tld_odessa.ua (0.000000)
# 995. tld_od.ua (0.000000)
# 996. tld_numazu.shizuoka.jp (0.000000)
# 997. tld_nc (0.000000)
# 998. tld_nagasaki.jp (0.000000)
# 999. tld_nagasaki.nagasaki.jp (0.000000)
# 1000. tld_name.tr (0.000000)
# 1001. tld_napoli.it (0.000000)
# 1002. tld_nara.jp (0.000000)
# 1003. tld_nat.tn (0.000000)
# 1004. tld_ne.kr (0.000000)
# 1005. tld_net.ge (0.000000)
# 1006. tld_nerima.tokyo.jp (0.000000)
# 1007. tld_net.ai (0.000000)
# 1008. tld_net.ar (0.000000)
# 1009. tld_net.az (0.000000)
# 1010. tld_net.bd (0.000000)
# 1011. tld_net.co (0.000000)
# 1012. tld_nagano.jp (0.000000)
# 1013. tld_na (0.000000)
# 1014. tld_n.se (0.000000)
# 1015. tld_mz (0.000000)
# 1016. tld_myftp.org (0.000000)
# 1017. tld_my (0.000000)
# 1018. tld_mw (0.000000)
# 1019. tld_music.museum (0.000000)
# 1020. tld_museum.no (0.000000)
# 1021. tld_mus.br (0.000000)
# 1022. tld_muni.il (0.000000)
# 1023. tld_msk.ru (0.000000)
# 1024. tld_ms.it (0.000000)
# 1025. tld_moriya.ibaraki.jp (0.000000)
# 1026. tld_modena.it (0.000000)
# 1027. tld_mobi (0.000000)
# 1028. tld_mo.it (0.000000)
# 1029. tld_net.et (0.000000)
# 1030. tld_net.hk (0.000000)
# 1031. tld_nu.ca (0.000000)
# 1032. tld_nl.eu.org (0.000000)
# 1033. tld_net.ye (0.000000)
# 1034. tld_news (0.000000)
# 1035. tld_ni (0.000000)
# 1036. tld_ni.sch.uk (0.000000)
# 1037. tld_niihama.ehime.jp (0.000000)
# 1038. tld_nl.ca (0.000000)
# 1039. tld_no-ip.info (0.000000)
# 1040. tld_net.id (0.000000)
# 1041. tld_no-ip.org (0.000000)
# 1042. tld_nom.fr (0.000000)
# 1043. tld_nom.pl (0.000000)
# 1044. tld_northants.sch.uk (0.000000)
# 1045. tld_nr (0.000000)
# 1046. tld_nt.ca (0.000000)
# 1047. tld_net.tw (0.000000)
# 1048. tld_net.tr (0.000000)
# 1049. tld_net.to (0.000000)
# 1050. tld_net.sg (0.000000)
# 1051. tld_net.sb (0.000000)
# 1052. tld_net.sa (0.000000)
# 1053. tld_net.ru (0.000000)
# 1054. tld_net.qa (0.000000)
# 1055. tld_net.py (0.000000)
# 1056. tld_net.ph (0.000000)
# 1057. tld_net.nr (0.000000)
# 1058. tld_net.my (0.000000)
# 1059. tld_net.mx (0.000000)
# 1060. tld_net.mt (0.000000)
# 1061. tld_net.mo (0.000000)
# 1062. tld_net.je (0.000000)
# 1063. tld_net.in (0.000000)
# 1064. tld_plymouth.sch.uk (0.000000)
# 1065. tld_podzone.net (0.000000)
# 1066. tld_mn (0.000000)
# 1067. tld_tuxfamily.org (0.000000)
# 1068. tld_toyonaka.osaka.jp (0.000000)
# 1069. tld_travel (0.000000)
# 1070. tld_trieste.it (0.000000)
# 1071. tld_ts.it (0.000000)
# 1072. tld_tsuruga.fukui.jp (0.000000)
# 1073. tld_tt (0.000000)
# 1074. tld_tw (0.000000)
# 1075. tld_toyama.toyama.jp (0.000000)
# 1076. tld_twmail.org (0.000000)
# 1077. tld_ua (0.000000)
# 1078. tld_ube.yamaguchi.jp (0.000000)
# 1079. tld_ukiha.fukuoka.jp (0.000000)
# 1080. tld_us.com (0.000000)
# 1081. tld_utsunomiya.tochigi.jp (0.000000)
# 1082. tld_toyohashi.aichi.jp (0.000000)
# 1083. tld_toyama.jp (0.000000)
# 1084. tld_police.uk (0.000000)
# 1085. tld_tochigi.jp (0.000000)
# 1086. tld_takarazuka.hyogo.jp (0.000000)
# 1087. tld_takatsuki.osaka.jp (0.000000)
# 1088. tld_tg (0.000000)
# 1089. tld_thruhere.net (0.000000)
# 1090. tld_tj (0.000000)
# 1091. tld_tl (0.000000)
# 1092. tld_tochigi.tochigi.jp (0.000000)
# 1093. tld_tottori.jp (0.000000)
# 1094. tld_tokamachi.niigata.jp (0.000000)
# 1095. tld_tokyo.jp (0.000000)
# 1096. tld_tomiya.miyagi.jp (0.000000)
# 1097. tld_tondabayashi.osaka.jp (0.000000)
# 1098. tld_torbay.sch.uk (0.000000)
# 1099. tld_torino.it (0.000000)
# 1100. tld_uz (0.000000)
# 1101. tld_uzhgorod.ua (0.000000)
# 1102. tld_va.it (0.000000)
# 1103. tld_yamaguchi.jp (0.000000)
# 1104. tld_wilts.sch.uk (0.000000)
# 1105. tld_wokingham.sch.uk (0.000000)
# 1106. tld_wroclaw.pl (0.000000)
# 1107. tld_x.se (0.000000)
# 1108. tld_yaizu.shizuoka.jp (0.000000)
# 1109. tld_yamagata.jp (0.000000)
# 1110. tld_yatsushiro.kumamoto.jp (0.000000)
# 1111. tld_vc (0.000000)
# 1112. tld_yokosuka.kanagawa.jp (0.000000)
# 1113. tld_z.se (0.000000)
# 1114. tld_za.com (0.000000)
# 1115. tld_za.net (0.000000)
# 1116. tld_za.org (0.000000)
# 1117. tld_zagan.pl (0.000000)
# 1118. tld_webhop.net (0.000000)
# 1119. tld_web.za (0.000000)
# 1120. tld_web.tr (0.000000)
# 1121. tld_web.gu (0.000000)
# 1122. tld_washingtondc.museum (0.000000)
# 1123. tld_warwickshire.sch.uk (0.000000)
# 1124. tld_waltham.sch.uk (0.000000)
# 1125. tld_walsall.sch.uk (0.000000)
# 1126. tld_wakefield.sch.uk (0.000000)
# 1127. tld_vladimir.ru (0.000000)
# 1128. tld_vinnica.ua (0.000000)
# 1129. tld_vic.au (0.000000)
# 1130. tld_vi (0.000000)
# 1131. tld_vet.br (0.000000)
# 1132. tld_venice.it (0.000000)
# 1133. tld_ve.it (0.000000)
# 1134. tld_ve (0.000000)
# 1135. tld_takamatsu.kagawa.jp (0.000000)
# 1136. tld_sz (0.000000)
# 1137. tld_sy (0.000000)
# 1138. tld_rzeszow.pl (0.000000)
# 1139. tld_ri.us (0.000000)
# 1140. tld_richmond.sch.uk (0.000000)
# 1141. tld_rnu.tn (0.000000)
# 1142. tld_ro.im (0.000000)
# 1143. tld_roma.it (0.000000)
# 1144. tld_rs (0.000000)
# 1145. tld_s3.amazonaws.com (0.000000)
# 1146. tld_sch.zm (0.000000)
# 1147. tld_sa.edu.au (0.000000)
# 1148. tld_sakai.osaka.jp (0.000000)
# 1149. tld_sapporo.jp (0.000000)
# 1150. tld_sc (0.000000)
# 1151. tld_sc.ug (0.000000)
# 1152. tld_sc.us (0.000000)
# 1153. tld_ravenna.it (0.000000)
# 1154. tld_py (0.000000)
# 1155. tld_pw (0.000000)
# 1156. tld_pvt.k12.ma.us (0.000000)
# 1157. tld_pulawy.pl (0.000000)
# 1158. tld_psc.br (0.000000)
# 1159. tld_ps (0.000000)
# 1160. tld_pro.br (0.000000)
# 1161. tld_pro (0.000000)
# 1162. tld_prd.fr (0.000000)
# 1163. tld_pr.gov.br (0.000000)
# 1164. tld_pr (0.000000)
# 1165. tld_ppg.br (0.000000)
# 1166. tld_pp.ru (0.000000)
# 1167. tld_post.ye (0.000000)
# 1168. tld_portsmouth.sch.uk (0.000000)
# 1169. tld_poole.sch.uk (0.000000)
# 1170. tld_sch.ae (0.000000)
# 1171. tld_schools.nsw.edu.au (0.000000)
# 1172. tld_swansea.sch.uk (0.000000)
# 1173. tld_srv.br (0.000000)
# 1174. tld_so.it (0.000000)
# 1175. tld_soma.fukushima.jp (0.000000)
# 1176. tld_soo.kagoshima.jp (0.000000)
# 1177. tld_southwark.sch.uk (0.000000)
# 1178. tld_spb.su (0.000000)
# 1179. tld_sr (0.000000)
# 1180. tld_st-helens.sch.uk (0.000000)
# 1181. tld_sci.eg (0.000000)
# 1182. tld_staffs.sch.uk (0.000000)
# 1183. tld_stardust.nom.br (0.000000)
# 1184. tld_stockport.sch.uk (0.000000)
# 1185. tld_suginami.tokyo.jp (0.000000)
# 1186. tld_sumy.ua (0.000000)
# 1187. tld_surrey.sch.uk (0.000000)
# 1188. tld_sn (0.000000)
# 1189. tld_slough.sch.uk (0.000000)
# 1190. tld_skoczow.pl (0.000000)
# 1191. tld_silk.museum (0.000000)
# 1192. tld_shizuoka.shizuoka.jp (0.000000)
# 1193. tld_shizuoka.jp (0.000000)
# 1194. tld_shinagawa.tokyo.jp (0.000000)
# 1195. tld_shimane.jp (0.000000)
# 1196. tld_sheffield.sch.uk (0.000000)
# 1197. tld_sh.cn (0.000000)
# 1198. tld_servegame.com (0.000000)
# 1199. tld_servebeer.com (0.000000)
# 1200. tld_servebbs.org (0.000000)
# 1201. tld_seoul.kr (0.000000)
# 1202. tld_sendai.jp (0.000000)
# 1203. tld_selfip.com (0.000000)
# 1204. tld_sefton.sch.uk (0.000000)
# 1205. tld_mo (0.000000)
# 1206. tld_mk (0.000000)
# 1207. tld_edu.do (0.000000)
# 1208. tld_gov.lk (0.000000)
# 1209. tld_gov.ir (0.000000)
# 1210. tld_gov.jm (0.000000)
# 1211. tld_gov.kh (0.000000)
# 1212. tld_gov.la (0.000000)
# 1213. tld_gov.lb (0.000000)
# 1214. tld_gov.lc (0.000000)
# 1215. tld_gov.ls (0.000000)
# 1216. tld_gov.gy (0.000000)
# 1217. tld_gov.lt (0.000000)
# 1218. tld_gov.lv (0.000000)
# 1219. tld_gov.ly (0.000000)
# 1220. tld_gov.ma (0.000000)
# 1221. tld_gov.mk (0.000000)
# 1222. tld_gov.mm (0.000000)
# 1223. tld_gov.ie (0.000000)
# 1224. tld_gov.gu (0.000000)
# 1225. tld_hk.com (0.000000)
# 1226. tld_gov.cm (0.000000)
# 1227. tld_gov.bf (0.000000)
# 1228. tld_gov.bh (0.000000)
# 1229. tld_gov.bt (0.000000)
# 1230. tld_gov.by (0.000000)
# 1231. tld_gov.bz (0.000000)
# 1232. tld_gov.ck (0.000000)
# 1233. tld_gov.cn (0.000000)
# 1234. tld_gov.gh (0.000000)
# 1235. tld_gov.co (0.000000)
# 1236. tld_gov.cu (0.000000)
# 1237. tld_gov.eg (0.000000)
# 1238. tld_gov.et (0.000000)
# 1239. tld_gov.fj (0.000000)
# 1240. tld_gov.ge (0.000000)
# 1241. tld_gov.mn (0.000000)
# 1242. tld_gov.mv (0.000000)
# 1243. tld_gov.mw (0.000000)
# 1244. tld_gunma.jp (0.000000)
# 1245. tld_gov.zw (0.000000)
# 1246. tld_gp (0.000000)
# 1247. tld_greenwich.sch.uk (0.000000)
# 1248. tld_gs (0.000000)
# 1249. tld_gs.hl.no (0.000000)
# 1250. tld_gt (0.000000)
# 1251. tld_hachioji.tokyo.jp (0.000000)
# 1252. tld_gov.my (0.000000)
# 1253. tld_hakusan.ishikawa.jp (0.000000)
# 1254. tld_hants.sch.uk (0.000000)
# 1255. tld_havering.sch.uk (0.000000)
# 1256. tld_higashikawa.hokkaido.jp (0.000000)
# 1257. tld_hikone.shiga.jp (0.000000)
# 1258. tld_hillingdon.sch.uk (0.000000)
# 1259. tld_gov.ye (0.000000)
# 1260. tld_gov.ws (0.000000)
# 1261. tld_gov.vn (0.000000)
# 1262. tld_gov.ua (0.000000)
# 1263. tld_gov.to (0.000000)
# 1264. tld_gov.tn (0.000000)
# 1265. tld_gov.sh (0.000000)
# 1266. tld_gov.sc (0.000000)
# 1267. tld_gov.sa (0.000000)
# 1268. tld_gov.rw (0.000000)
# 1269. tld_gov.qa (0.000000)
# 1270. tld_gov.pt (0.000000)
# 1271. tld_gov.ps (0.000000)
# 1272. tld_gov.pk (0.000000)
# 1273. tld_gov.pg (0.000000)
# 1274. tld_zm (0.000000)
# 1275. tld_gov.mz (0.000000)
# 1276. tld_gov.bd (0.000000)
# 1277. tld_gov.bb (0.000000)
# 1278. tld_gov.ba (0.000000)
# 1279. tld_fedorapeople.org (0.000000)
# 1280. tld_ehime.jp (0.000000)
# 1281. tld_emilia-romagna.it (0.000000)
# 1282. tld_eng.br (0.000000)
# 1283. tld_essex.sch.uk (0.000000)
# 1284. tld_eti.br (0.000000)
# 1285. tld_fe.it (0.000000)
# 1286. tld_fi.it (0.000000)
# 1287. tld_fuji.shizuoka.jp (0.000000)
# 1288. tld_fife.sch.uk (0.000000)
# 1289. tld_firenze.it (0.000000)
# 1290. tld_firm.in (0.000000)
# 1291. tld_folkebibl.no (0.000000)
# 1292. tld_fot.br (0.000000)
# 1293. tld_freedesktop.org (0.000000)
# 1294. tld_edu.za (0.000000)
# 1295. tld_edu.uy (0.000000)
# 1296. tld_edu.ua (0.000000)
# 1297. tld_edu.tt (0.000000)
# 1298. tld_edu.sv (0.000000)
# 1299. tld_edu.qa (0.000000)
# 1300. tld_edu.pe (0.000000)
# 1301. tld_edu.ng (0.000000)
# 1302. tld_edu.mn (0.000000)
# 1303. tld_edu.lv (0.000000)
# 1304. tld_edu.kh (0.000000)
# 1305. tld_edu.jm (0.000000)
# 1306. tld_edu.in (0.000000)
# 1307. tld_edu.gy (0.000000)
# 1308. tld_edu.gh (0.000000)
# 1309. tld_edu.ge (0.000000)
# 1310. tld_edu.et (0.000000)
# 1311. tld_from.hr (0.000000)
# 1312. tld_fukui.jp (0.000000)
# 1313. tld_gov.az (0.000000)
# 1314. tld_gob.ni (0.000000)
# 1315. tld_go.dyndns.org (0.000000)
# 1316. tld_go.id (0.000000)
# 1317. tld_go.ke (0.000000)
# 1318. tld_go.tz (0.000000)
# 1319. tld_go.ug (0.000000)
# 1320. tld_gob.gt (0.000000)
# 1321. tld_gob.pa (0.000000)
# 1322. tld_fukushima.jp (0.000000)
# 1323. tld_gob.pe (0.000000)
# 1324. tld_googlecode.com (0.000000)
# 1325. tld_gotdns.org (0.000000)
# 1326. tld_gov.ac (0.000000)
# 1327. tld_gov.ae (0.000000)
# 1328. tld_gov.al (0.000000)
# 1329. tld_gniezno.pl (0.000000)
# 1330. tld_gm (0.000000)
# 1331. tld_gloucs.sch.uk (0.000000)
# 1332. tld_gliwice.pl (0.000000)
# 1333. tld_gl (0.000000)
# 1334. tld_gh (0.000000)
# 1335. tld_gg (0.000000)
# 1336. tld_gf (0.000000)
# 1337. tld_gen.tr (0.000000)
# 1338. tld_gd.cn (0.000000)
# 1339. tld_gb.net (0.000000)
# 1340. tld_game-host.org (0.000000)
# 1341. tld_gamagori.aichi.jp (0.000000)
# 1342. tld_fylkesbibl.no (0.000000)
# 1343. tld_fvg.it (0.000000)
# 1344. tld_funabashi.chiba.jp (0.000000)
# 1345. tld_fukuyama.hiroshima.jp (0.000000)
# 1346. tld_hiroshima.jp (0.000000)
# 1347. tld_hm (0.000000)
# 1348. tld_miyazaki.miyazaki.jp (0.000000)
# 1349. tld_lib.de.us (0.000000)
# 1350. tld_leeds.sch.uk (0.000000)
# 1351. tld_leics.sch.uk (0.000000)
# 1352. tld_lewisham.sch.uk (0.000000)
# 1353. tld_lib.ar.us (0.000000)
# 1354. tld_lib.az.us (0.000000)
# 1355. tld_lib.ca.us (0.000000)
# 1356. tld_lib.ga.us (0.000000)
# 1357. tld_law.za (0.000000)
# 1358. tld_lib.la.us (0.000000)
# 1359. tld_lib.ma.us (0.000000)
# 1360. tld_lib.md.us (0.000000)
# 1361. tld_lib.me.us (0.000000)
# 1362. tld_lib.mn.us (0.000000)
# 1363. tld_lib.ms.us (0.000000)
# 1364. tld_lbhf.sch.uk (0.000000)
# 1365. tld_law.pro (0.000000)
# 1366. tld_hn (0.000000)
# 1367. tld_kr (0.000000)
# 1368. tld_kitahiroshima.hokkaido.jp (0.000000)
# 1369. tld_knowsley.sch.uk (0.000000)
# 1370. tld_kobe.jp (0.000000)
# 1371. tld_kochi.jp (0.000000)
# 1372. tld_komaki.aichi.jp (0.000000)
# 1373. tld_koori.fukushima.jp (0.000000)
# 1374. tld_kumamoto.jp (0.000000)
# 1375. tld_lancs.sch.uk (0.000000)
# 1376. tld_kumamoto.kumamoto.jp (0.000000)
# 1377. tld_kurume.fukuoka.jp (0.000000)
# 1378. tld_kw (0.000000)
# 1379. tld_ky (0.000000)
# 1380. tld_kyoto.jp (0.000000)
# 1381. tld_la (0.000000)
# 1382. tld_lib.ne.us (0.000000)
# 1383. tld_lib.nv.us (0.000000)
# 1384. tld_lib.or.us (0.000000)
# 1385. tld_middlesbrough.sch.uk (0.000000)
# 1386. tld_med.pro (0.000000)
# 1387. tld_med.sa (0.000000)
# 1388. tld_media.pl (0.000000)
# 1389. tld_meiwa.mie.jp (0.000000)
# 1390. tld_merseine.nu (0.000000)
# 1391. tld_mg (0.000000)
# 1392. tld_midori.gunma.jp (0.000000)
# 1393. tld_lib.tx.us (0.000000)
# 1394. tld_mihara.hiroshima.jp (0.000000)
# 1395. tld_mil.ar (0.000000)
# 1396. tld_mil.nz (0.000000)
# 1397. tld_mil.pl (0.000000)
# 1398. tld_mil.za (0.000000)
# 1399. tld_milano.it (0.000000)
# 1400. tld_med.br (0.000000)
# 1401. tld_me (0.000000)
# 1402. tld_matsuyama.ehime.jp (0.000000)
# 1403. tld_marche.it (0.000000)
# 1404. tld_maori.nz (0.000000)
# 1405. tld_manchester.sch.uk (0.000000)
# 1406. tld_machida.tokyo.jp (0.000000)
# 1407. tld_m.se (0.000000)
# 1408. tld_lviv.ua (0.000000)
# 1409. tld_lucas.nom.br (0.000000)
# 1410. tld_london.museum (0.000000)
# 1411. tld_lk (0.000000)
# 1412. tld_liverpool.sch.uk (0.000000)
# 1413. tld_lima-city.de (0.000000)
# 1414. tld_lib.wi.us (0.000000)
# 1415. tld_lib.wa.us (0.000000)
# 1416. tld_lib.ut.us (0.000000)
# 1417. tld_kita.tokyo.jp (0.000000)
# 1418. tld_kirklees.sch.uk (0.000000)
# 1419. tld_kicks-ass.org (0.000000)
# 1420. tld_ind.br (0.000000)
# 1421. tld_if.ua (0.000000)
# 1422. tld_iki.fi (0.000000)
# 1423. tld_iki.nagasaki.jp (0.000000)
# 1424. tld_im (0.000000)
# 1425. tld_in-berlin.de (0.000000)
# 1426. tld_in.th (0.000000)
# 1427. tld_ind.in (0.000000)
# 1428. tld_je (0.000000)
# 1429. tld_inf.br (0.000000)
# 1430. tld_info.au (0.000000)
# 1431. tld_io (0.000000)
# 1432. tld_is.it (0.000000)
# 1433. tld_ishikawa.jp (0.000000)
# 1434. tld_islington.sch.uk (0.000000)
# 1435. tld_idv.tw (0.000000)
# 1436. tld_ichihara.chiba.jp (0.000000)
# 1437. tld_ibaraki.osaka.jp (0.000000)
# 1438. tld_ibaraki.jp (0.000000)
# 1439. tld_i.se (0.000000)
# 1440. tld_i.ph (0.000000)
# 1441. tld_hyogo.jp (0.000000)
# 1442. tld_house.museum (0.000000)
# 1443. tld_hounslow.sch.uk (0.000000)
# 1444. tld_homeunix.org (0.000000)
# 1445. tld_homeunix.net (0.000000)
# 1446. tld_homeunix.com (0.000000)
# 1447. tld_homeoffice.gov.uk (0.000000)
# 1448. tld_homelinux.org (0.000000)
# 1449. tld_homelinux.net (0.000000)
# 1450. tld_homelinux.com (0.000000)
# 1451. tld_hokkaido.jp (0.000000)
# 1452. tld_izumi.sendai.jp (0.000000)
# 1453. tld_jo (0.000000)
# 1454. tld_kicks-ass.net (0.000000)
# 1455. tld_kamakura.kanagawa.jp (0.000000)
# 1456. tld_k12.tx.us (0.000000)
# 1457. tld_k12.wa.us (0.000000)
# 1458. tld_k12.wi.us (0.000000)
# 1459. tld_k12.wy.us (0.000000)
# 1460. tld_kaga.ishikawa.jp (0.000000)
# 1461. tld_kagawa.jp (0.000000)
# 1462. tld_kanagawa.jp (0.000000)
# 1463. tld_jobs (0.000000)
# 1464. tld_kani.gifu.jp (0.000000)
# 1465. tld_kashiwazaki.niigata.jp (0.000000)
# 1466. tld_kawasaki.jp (0.000000)
# 1467. tld_kent.sch.uk (0.000000)
# 1468. tld_keymachine.de (0.000000)
# 1469. tld_kherson.ua (0.000000)
# 1470. tld_k12.tr (0.000000)
# 1471. tld_k12.tn.us (0.000000)
# 1472. tld_k12.ok.us (0.000000)
# 1473. tld_k12.oh.us (0.000000)
# 1474. tld_k12.nv.us (0.000000)
# 1475. tld_k12.nm.us (0.000000)
# 1476. tld_k12.nj.us (0.000000)
# 1477. tld_k12.nh.us (0.000000)
# 1478. tld_k12.ms.us (0.000000)
# 1479. tld_k12.mo.us (0.000000)
# 1480. tld_k12.mn.us (0.000000)
# 1481. tld_k12.ky.us (0.000000)
# 1482. tld_k12.de.us (0.000000)
# 1483. tld_k12.ct.us (0.000000)
# 1484. tld_k12.co.us (0.000000)
# 1485. tld_k12.al.us (0.000000)
# 1486. tld_js.cn (0.000000)
# 1487. tld_gov.om (0.000000)

# %%
y_pred = model.predict(x_test)

# %%
classification = classification_report(y_test, y_pred, zero_division=1)
print("\nClassification Report:\n", classification)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.55      0.54        20
#            1       0.53      0.50      0.51        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40

# %%
with open(r'..\PickleFiles\Model.pkl', 'wb') as model_pkl:
    pickle.dump(model, model_pkl)
