# %%
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, KFold

# %%
df_train = pd.read_csv(r'C:\Users\nadin\OneDrive\Documents\Machine Learning Project\train_dump.csv')

# %%
columns_to_convert = df_train.columns[8:-1]
df_train[columns_to_convert] = df_train[columns_to_convert].astype('int8')

# %%
df_test = pd.read_csv(r'C:\Users\nadin\OneDrive\Documents\Machine Learning Project\test_dump.csv')

# %%
df_test[columns_to_convert] = df_test[columns_to_convert].astype('int8')

# %%
df_train = df_train.iloc[:, 1:]
df_test = df_test.iloc[:, 1:]

# %%
x_train = df_train[df_train.columns[:-1]].to_numpy()
y_train = df_train['label'].to_numpy()

x_test = df_test[df_test.columns[:-1]].to_numpy()
y_test = df_test['label'].to_numpy()

# %%
kf = KFold(n_splits=5)
model = KNeighborsClassifier()

# %%
param_grid = {"n_neighbors": [1,3,5,7,9]}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kf, verbose=3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# [I] [16:09:01.042584] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [I] [16:09:01.139922] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END .....................n_neighbors=1;, score=0.998 total time= 2.4min
# [I] [16:11:27.818846] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END .....................n_neighbors=1;, score=0.998 total time= 2.4min
# [I] [16:13:49.544658] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END .....................n_neighbors=1;, score=0.998 total time= 9.2min
# [I] [16:23:02.013565] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END .....................n_neighbors=1;, score=0.998 total time= 2.4min
# [I] [16:25:28.930485] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END .....................n_neighbors=1;, score=0.999 total time= 2.3min
# [I] [16:27:44.342705] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END .....................n_neighbors=3;, score=0.999 total time= 2.0min
# [I] [16:29:46.637790] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END .....................n_neighbors=3;, score=0.999 total time= 2.0min
# [I] [16:31:44.942594] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END .....................n_neighbors=3;, score=0.999 total time= 2.0min
# [I] [16:33:47.244695] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END .....................n_neighbors=3;, score=0.999 total time= 2.0min
# [I] [16:35:45.322021] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END .....................n_neighbors=3;, score=0.999 total time= 2.0min
# [I] [16:37:47.797605] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END .....................n_neighbors=5;, score=0.999 total time= 2.0min
# [I] [16:39:47.158159] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END .....................n_neighbors=5;, score=0.999 total time= 2.0min
# [I] [16:41:45.967080] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END .....................n_neighbors=5;, score=0.999 total time= 2.0min
# [I] [16:43:45.113204] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END .....................n_neighbors=5;, score=0.999 total time= 2.0min
# [I] [16:45:43.777799] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END .....................n_neighbors=5;, score=0.999 total time= 2.0min
# [I] [16:47:43.250883] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END .....................n_neighbors=7;, score=0.999 total time= 1.9min
# [I] [16:49:36.790165] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END .....................n_neighbors=7;, score=0.999 total time= 2.0min
# [I] [16:51:35.164747] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END .....................n_neighbors=7;, score=0.999 total time= 1.9min
# [I] [16:53:28.847345] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END .....................n_neighbors=7;, score=0.999 total time= 2.0min
# [I] [16:55:27.303125] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END .....................n_neighbors=7;, score=0.999 total time= 2.0min
# [I] [16:57:25.368256] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END .....................n_neighbors=9;, score=0.999 total time= 2.0min
# [I] [16:59:22.994320] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END .....................n_neighbors=9;, score=0.999 total time= 2.0min
# [I] [17:01:21.058632] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END .....................n_neighbors=9;, score=0.999 total time= 2.0min
# [I] [17:03:18.864938] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END .....................n_neighbors=9;, score=0.999 total time= 2.0min
# [I] [17:05:16.923268] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END .....................n_neighbors=9;, score=0.999 total time= 2.0min
# [I] [17:07:14.680620] Unused keyword parameter: n_jobs during cuML estimator initialization
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9]}, verbose=3)

# %%
best_k = grid_search.best_params_["n_neighbors"]
print(best_k)
# Out:
# 9

# %%
model_best = KNeighborsClassifier(n_neighbors=best_k)
model_best.fit(x_train, y_train)

# %%
y_pred = model_best.predict(x_test)

# %%
classification = classification_report(y_test, y_pred, zero_division=1)

print("\nClassification Report:\n", classification)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98      8062
#            1       1.00      1.00      1.00    353872
#
#     accuracy                           1.00    361934
#    macro avg       1.00      0.98      0.99    361934
# weighted avg       1.00      1.00      1.00    361934
