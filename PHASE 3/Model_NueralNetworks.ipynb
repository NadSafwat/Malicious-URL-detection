# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report

# %%
df_train = pd.read_csv(r'C:\Users\nadin\OneDrive\Documents\Machine Learning Project\train_dump.csv')

# %%
columns_to_convert = df_train.columns[8:-1]
df_train[columns_to_convert] = df_train[columns_to_convert].astype('int8')

# %%
df_test = pd.read_csv(r'C:\Users\nadin\OneDrive\Documents\Machine Learning Project\test_dump.csv')

# %%
df_test[columns_to_convert] = df_test[columns_to_convert].astype('int8')

# %%
# remove the index column thats read from the csv
df_train = df_train.iloc[:, 1:]
df_test = df_test.iloc[:, 1:]

# %%
x_train = df_train[df_train.columns[:-1]].to_numpy()
y_train = df_train['label'].to_numpy()

x_test = df_test[df_test.columns[:-1]].to_numpy()
y_test = df_test['label'].to_numpy()

# %%
kf = KFold(n_splits=5)

f1s = []
accuracies = []
precisions = []
recalls = []
roc_aucs = []

# %%
model = Sequential()
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2)) 
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2)) 
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='loss', patience=5)

fold = 1
for train, valid in kf.split(x_train, y_train):
    print(f"##### FOLD: {fold} #####")

    # Fit the model
    model.fit(x_train[train], y_train[train], epochs=200, batch_size= 256, callbacks=[early_stopping])

    # Predict on the test set
    predictions = model.predict(x_train[valid])
    predictions = np.argmax(predictions, axis=1)

    # Evaluate the model
    precision = precision_score(y_true=y_train[valid], y_pred=predictions, zero_division=0)
    recall = recall_score(y_true=y_train[valid], y_pred=predictions, zero_division=0)
    accuracy = accuracy_score(y_true=y_train[valid], y_pred=predictions)
    f1 = f1_score(y_true=y_train[valid], y_pred=predictions, zero_division=0)

    # Store the result
    f1s.append(f1)
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)

    # Print the scores for each fold
    print(f"Precision = {precision}")
    print(f"Recall = {recall}")
    print(f"Accuracy = {accuracy}")
    print(f"F1 score = {f1}\n")

    fold += 1

print("\nMean Scores: ")
print(f"Mean F1 score = {np.mean(f1s)}")
print(f"Mean Accuracy = {np.mean(accuracies)}")
print(f"Mean Precision = {np.mean(precisions)}")
print(f"Mean Recall = {np.mean(recalls)}")
# Out:
# ##### FOLD: 1 #####
# Epoch 1/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - accuracy: 0.9957 - loss: 0.0209
# Epoch 2/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9988 - loss: 0.0033
# Epoch 3/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9988 - loss: 0.0033
# Epoch 4/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9989 - loss: 0.0031
# Epoch 5/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9989 - loss: 0.0029
# Epoch 6/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9989 - loss: 0.0029
# Epoch 7/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9989 - loss: 0.0029
# Epoch 8/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9989 - loss: 0.0028
# Epoch 9/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9989 - loss: 0.0028
# Epoch 10/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0028
# Epoch 11/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9989 - loss: 0.0029
# Epoch 12/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9989 - loss: 0.0027
# Epoch 13/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 14/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9989 - loss: 0.0027
# Epoch 15/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 16/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 17/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 18/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 19/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 20/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 21/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 22/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 23/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 24/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 25/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 26/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 27/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 28/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 29/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 30/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 31/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 32/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 33/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 34/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 35/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 36/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 37/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 38/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 39/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 40/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9990 - loss: 0.0024
# Epoch 41/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 42/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 43/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 44/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 45/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 46/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9992 - loss: 0.0023
# Epoch 47/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 48/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 49/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 50/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 51/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 52/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 53/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 54/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 55/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9992 - loss: 0.0021
# Epoch 56/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9992 - loss: 0.0023
# Epoch 57/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 58/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9991 - loss: 0.0023
# Epoch 59/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 60/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 61/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - accuracy: 0.9991 - loss: 0.0024
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step
# Precision = 0.999032873770855
# Recall = 0.9996504256706925
# Accuracy = 0.9987125
# F1 score = 0.9993415543153763
#
# ##### FOLD: 2 #####
# Epoch 1/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0038
# Epoch 2/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 3/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 4/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9990 - loss: 0.0027
# Epoch 5/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9991 - loss: 0.0026
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Precision = 0.9992710873160667
# Recall = 0.9997398565372773
# Accuracy = 0.9990333333333333
# F1 score = 0.9995054169633454
#
# ##### FOLD: 3 #####
# Epoch 1/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9990 - loss: 0.0028
# Epoch 2/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9990 - loss: 0.0028
# Epoch 3/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 4/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 5/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0026
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Precision = 0.999156283556904
# Recall = 0.9998379641474355
# Accuracy = 0.9990166666666667
# F1 score = 0.9994970076216133
#
# ##### FOLD: 4 #####
# Epoch 1/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 2/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 3/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9991 - loss: 0.0028
# Epoch 4/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 5/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.9991 - loss: 0.0024
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Precision = 0.9991264663646939
# Recall = 0.9998763342046797
# Accuracy = 0.999025
# F1 score = 0.9995012596391166
#
# ##### FOLD: 5 #####
# Epoch 1/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0026
# Epoch 2/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 3/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.9991 - loss: 0.0025
# Epoch 4/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9990 - loss: 0.0025
# Epoch 5/200
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9991 - loss: 0.0026
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Precision = 0.9991314270143229
# Recall = 0.999970171005365
# Accuracy = 0.9991208333333333
# F1 score = 0.9995506230579355
#
#
# Mean Scores:
# Mean F1 score = 0.9994791723194775
# Mean Accuracy = 0.9989816666666667
# Mean Precision = 0.9991436276045687
# Mean Recall = 0.99981495031309

# %%
y_pred = model.predict(x_test)
# Out:
# 11311/11311 ━━━━━━━━━━━━━━━━━━━━ 10s 870us/step

# %%
y_pred = np.argmax(y_pred, axis=1)

classification = classification_report(y_test, y_pred, zero_division=1)

print("\nClassification Report:\n", classification)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98      8062
#            1       1.00      1.00      1.00    353872
#
#     accuracy                           1.00    361934
#    macro avg       1.00      0.98      0.99    361934
# weighted avg       1.00      1.00      1.00    361934
